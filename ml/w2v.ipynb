# %%
import pandas as pd
import numpy as np
import os
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import re
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

folder_path_train = "..\\data\\cleaned\\train"
folder_path_test = "..\\data\\cleaned\\test"
names = ["Facebook", "Reddit", "Twitter", "Youtube"]
dfs_train = {}
dfs_test = {}

df_combined_train = pd.DataFrame(columns=["text", "label"])
df_combined_test = pd.DataFrame(columns=["text", "label"])
for n in names:
    dfs_train[n] = pd.read_csv(os.path.join(folder_path_train, f"{n.lower()}_train.csv"))
    dfs_test[n] = pd.read_csv(os.path.join(folder_path_test, f"{n.lower()}_test.csv"))
    df_combined_train = pd.concat([df_combined_train, dfs_train[n]], ignore_index=True)
    df_combined_test = pd.concat([df_combined_test, dfs_test[n]], ignore_index=True)

# %%
nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vital\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vital\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Tokenize
    tokens = word_tokenize(text)
    # Remove stop words
    tokens = [word for word in tokens if word not in stop_words]
    return tokens

for name in names:
    dfs_train[name]['tokens'] = dfs_train[name]['text'].apply(preprocess_text)
    dfs_test[name]['tokens'] = dfs_train[name]['text'].apply(preprocess_text)
    dfs_train[name]['label'] = dfs_train[name]['label'].astype(int)
    dfs_test[name]['label'] = dfs_test[name]['label'].astype(int)

df_combined_train['tokens'] = df_combined_train['text'].apply(preprocess_text)
df_combined_test['tokens'] = df_combined_test['text'].apply(preprocess_text)
df_combined_train['label'] = df_combined_train['label'].astype(int)
df_combined_test['label'] = df_combined_test['label'].astype(int)

# %%
#dO DATA cleaning 
#search: data cleaning in text mining to clean twitter data
# after data cleaning i need to check the data

# %%
word2vec_models = {}
for name in dfs_train.keys():
    sentences = dfs_train[name]['tokens'].tolist()
    model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
    word2vec_models[name] = model

def get_sentence_embedding(tokens, model):
    # Get the embeddings for each token
    embeddings = [model.wv[word] for word in tokens if word in model.wv]
    # Average the embeddings to get the sentence embedding
    if embeddings:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(model.vector_size)

for name in dfs_train.keys():
    dfs_train[name]['embedding'] = dfs_train[name]['tokens'].apply(lambda x: get_sentence_embedding(x, word2vec_models[name]))
    dfs_test[name]['embedding'] = dfs_test[name]['tokens'].apply(lambda x: get_sentence_embedding(x, word2vec_models[name]))


def combined_dataset_w2v(training_df, testing_df):
    sentences = training_df['tokens'].tolist()
    model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
    training_df['embedding'] = training_df['tokens'].apply(lambda x: get_sentence_embedding(x, model))
    testing_df['embedding'] = testing_df['tokens'].apply(lambda x: get_sentence_embedding(x, model))
    for name in dfs_train.keys():
        dfs_train[name]['embedding_combined'] = dfs_train[name]['tokens'].apply(lambda x: get_sentence_embedding(x, model))
        dfs_test[name]['embedding_combined'] = dfs_test[name]['tokens'].apply(lambda x: get_sentence_embedding(x, model))

combined_dataset_w2v(df_combined_train, df_combined_test)

# %%
for name in dfs_train.keys():
    print(f"Class distribution in train set for {name}:")
    print(dfs_train[name]['label'].value_counts())
    print(f"Class distribution in test set for {name}:")
    print(dfs_test[name]['label'].value_counts())
# Out:
# Class distribution in train set for Facebook:
# label
# 1    844
# 0    352
# Name: count, dtype: int64
# Class distribution in test set for Facebook:
# label
# 1    212
# 0     88
# Name: count, dtype: int64
# Class distribution in train set for Reddit:
# label
# 0    10494
# 1     2942
# Name: count, dtype: int64
# Class distribution in test set for Reddit:
# label
# 0    2624
# 1     735
# Name: count, dtype: int64
# Class distribution in train set for Twitter:
# label
# 1    16123
# 0     3233
# Name: count, dtype: int64
# Class distribution in test set for Twitter:
# label
# 1    4031
# 0     808
# Name: count, dtype: int64
# Class distribution in train set for Youtube:
# label
# 1    1856
# 0     656
# Name: count, dtype: int64
# Class distribution in test set for Youtube:
# label
# 1    465
# 0    164
# Name: count, dtype: int64

# %%
for name in dfs_train.keys():
    X_test = np.vstack(dfs_test[name]['embedding'].values)
    y_test = dfs_test[name]['label']
    
    classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    classifier.fit(np.vstack(dfs_train[name]['embedding'].values), dfs_train[name]['label'])
    y_pred = classifier.predict(X_test)
    
    print(f"Predicted class distribution for {name}:")
    print(pd.Series(y_pred).value_counts())
# Out:
# Predicted class distribution for Facebook:
# 1    213
# 0     87
# Name: count, dtype: int64
# Predicted class distribution for Reddit:
# 0    2612
# 1     747
# Name: count, dtype: int64
# Predicted class distribution for Twitter:
# 1    4066
# 0     773
# Name: count, dtype: int64
# Predicted class distribution for Youtube:
# 1    474
# 0    155
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Plot embeddings for each dataset
fig, axs = plt.subplots(2, 2, figsize=(14, 12))

datasets = ["Facebook", "Reddit", "Twitter", "Youtube"]
for ax, name in zip(axs.flatten(), datasets):
    pca = PCA(n_components=2)
    embeddings = np.vstack(dfs_train[name]['embedding'].values)
    labels = dfs_train[name]['label'].values
    reduced_embeddings = pca.fit_transform(embeddings)
    
    ax.scatter(reduced_embeddings[labels == 0, 0], reduced_embeddings[labels == 0, 1], c='red', label='Class 0', alpha=0.5)
    ax.scatter(reduced_embeddings[labels == 1, 0], reduced_embeddings[labels == 1, 1], c='blue', label='Class 1', alpha=0.5)
    ax.set_title(f'PCA of W2V {name} Embeddings')
    ax.set_xlabel('PCA Component 1')
    ax.set_ylabel('PCA Component 2')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
# Plot embeddings for each dataset
fig, ax = plt.subplots(figsize=(14, 12))

dataset = df_combined_train
pca = PCA(n_components=2)
embeddings = np.vstack(dataset['embedding'].values)
labels = dataset['label'].values
reduced_embeddings = pca.fit_transform(embeddings)

ax.scatter(reduced_embeddings[labels == 0, 0], reduced_embeddings[labels == 0, 1], c='red', label='Class 0', alpha=0.5)
ax.scatter(reduced_embeddings[labels == 1, 0], reduced_embeddings[labels == 1, 1], c='blue', label='Class 1', alpha=0.5)
ax.set_title(f'PCA of Combined W2V Embeddings')
ax.set_xlabel('PCA Component 1')
ax.set_ylabel('PCA Component 2')
ax.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

results = []

# Train on each dataset and test on all datasets
for train_name in names:
    # Prepare training data
    X_train = np.vstack(dfs_train[train_name]['embedding'].values)
    y_train = dfs_train[train_name]['label']
    
    # Train the classifier
    classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    classifier.fit(X_train, y_train)
    
    for test_name in names:
        # Prepare testing data
        X_test = np.vstack(dfs_test[test_name]['embedding'].values)
        y_test = dfs_test[test_name]['label']
        
        # Predict on the test data
        y_pred = classifier.predict(X_test)
        report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
        recall = recall_score(y_test, y_pred, average='weighted')
        f1 = f1_score(y_test, y_pred, average='weighted')
        
        # Collect results for each class
        for cls in ['0', '1']:
            results.append({
                'Train Dataset': train_name,
                'Test Dataset': test_name,
                'Class': cls,
                'Precision': report[cls]['precision'],
                'Recall': report[cls]['recall'],
                'F1-Score': report[cls]['f1-score'],
                'Accuracy': np.nan  # Accuracy is not class-specific
            })
        
        # Include the overall metrics for the test dataset
        results.append({
            'Train Dataset': train_name,
            'Test Dataset': test_name,
            'Class': 'overall',
            'Precision': precision,
            'Recall': recall,
            'F1-Score': f1,
            'Accuracy': accuracy
        })

# Train on combined datasets and test on each dataset separately
X_train_combined = np.vstack(df_combined_train['embedding'].values)
y_train_combined = np.hstack(df_combined_train['label'])

# Train the classifier on combined datasets
classifier_combined = RandomForestClassifier(n_estimators=100, random_state=42)
classifier_combined.fit(X_train_combined, y_train_combined)

for test_name in names:
    # Prepare testing data
    X_test = np.vstack(dfs_test[test_name]['embedding_combined'].values)
    y_test = dfs_test[test_name]['label']
    
    # Predict on the test data
    y_pred = classifier_combined.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    # Collect results for each class
    for cls in ['0', '1']:
        results.append({
            'Train Dataset': 'combined',
            'Test Dataset': test_name,
            'Class': cls,
            'Precision': report[cls]['precision'],
            'Recall': report[cls]['recall'],
            'F1-Score': report[cls]['f1-score'],
            'Accuracy': np.nan  # Accuracy is not class-specific
        })
    
    # Include the overall metrics for the test dataset
    results.append({
        'Train Dataset': 'combined',
        'Test Dataset': test_name,
        'Class': 'overall',
        'Precision': precision,
        'Recall': recall,
        'F1-Score': f1,
        'Accuracy': accuracy
    })

results_df = pd.DataFrame(results)

# Save the results DataFrame to a CSV file
results_df.to_csv('results/w2v_classification_results.csv', index=False)

# Display the results DataFrame
print(results_df)
# Out:
#    Train Dataset Test Dataset    Class  Precision    Recall  F1-Score  \
# 0       Facebook     Facebook        0   0.321839  0.318182  0.320000
# 1       Facebook     Facebook        1   0.718310  0.721698  0.720000
# 2       Facebook     Facebook  overall   0.602012  0.603333  0.602667
# 3       Facebook       Reddit        0   0.780961  0.997332  0.875983
# 4       Facebook       Reddit        1   0.125000  0.001361  0.002692
# 5       Facebook       Reddit  overall   0.637427  0.779399  0.684894
# 6       Facebook      Twitter        0   0.167046  1.000000  0.286271
# 7       Facebook      Twitter        1   1.000000  0.000496  0.000992
# 8       Facebook      Twitter  overall   0.860916  0.167390  0.048627
# 9       Facebook      Youtube        0   0.259554  0.993902  0.411616
# 10      Facebook      Youtube        1   0.000000  0.000000  0.000000
# 11      Facebook      Youtube  overall   0.067674  0.259141  0.107321
# 12        Reddit     Facebook        0   0.293333  1.000000  0.453608
# 13        Reddit     Facebook        1   0.000000  0.000000  0.000000
# 14        Reddit     Facebook  overall   0.086044  0.293333  0.133058
# 15        Reddit       Reddit        0   0.778033  0.774771  0.776399
# 16        Reddit       Reddit        1   0.207775  0.210884  0.209318
# 17        Reddit       Reddit  overall   0.653252  0.651384  0.652313
# 18        Reddit      Twitter        0   0.192593  0.064356  0.096475
# 19        Reddit      Twitter        1   0.834537  0.945919  0.886744
# 20        Reddit      Twitter  overall   0.727347  0.798719  0.754788
# 21        Reddit      Youtube        0   0.261029  0.865854  0.401130
# 22        Reddit      Youtube        1   0.741176  0.135484  0.229091
# 23        Reddit      Youtube  overall   0.615987  0.325914  0.273947
# 24       Twitter     Facebook        0   0.311203  0.852273  0.455927
# 25       Twitter     Facebook        1   0.779661  0.216981  0.339483
# 26       Twitter     Facebook  overall   0.642247  0.403333  0.373640
# 27       Twitter       Reddit        0   0.785175  0.435976  0.560647
# 28       Twitter       Reddit        1   0.221872  0.574150  0.320061
# 29       Twitter       Reddit  overall   0.661916  0.466210  0.508003
# 30       Twitter      Twitter        0   0.183700  0.175743  0.179633
# 31       Twitter      Twitter        1   0.836203  0.843463  0.839817
# 32       Twitter      Twitter  overall   0.727250  0.731969  0.729582
# 33       Twitter      Youtube        0   0.251366  0.280488  0.265130
# 34       Twitter      Youtube        1   0.735426  0.705376  0.720088
# 35       Twitter      Youtube  overall   0.609216  0.594595  0.601466
# 36       Youtube     Facebook        0   0.295455  0.738636  0.422078
# 37       Youtube     Facebook        1   0.712500  0.268868  0.390411
# 38       Youtube     Facebook  overall   0.590167  0.406667  0.399700
# 39       Youtube       Reddit        0   0.739130  0.038872  0.073860
# 40       Youtube       Reddit        1   0.217013  0.951020  0.353387
# 41       Youtube       Reddit  overall   0.624883  0.238464  0.135024
# 42       Youtube      Twitter        0   0.163636  0.367574  0.226458
# 43       Youtube      Twitter        1   0.831019  0.623419  0.712403
# 44       Youtube      Twitter  overall   0.719581  0.580698  0.631261
# 45       Youtube      Youtube        0   0.264516  0.250000  0.257053
# 46       Youtube      Youtube        1   0.740506  0.754839  0.747604
# 47       Youtube      Youtube  overall   0.616401  0.623211  0.619702
# 48      combined     Facebook        0   0.321839  0.318182  0.320000
# 49      combined     Facebook        1   0.718310  0.721698  0.720000
# 50      combined     Facebook  overall   0.602012  0.603333  0.602667
# 51      combined       Reddit        0   0.778246  0.774390  0.776313
# 52      combined       Reddit        1   0.208556  0.212245  0.210384
# 53      combined       Reddit  overall   0.653589  0.651384  0.652479
# 54      combined      Twitter        0   0.183700  0.175743  0.179633
# 55      combined      Twitter        1   0.836203  0.843463  0.839817
# 56      combined      Twitter  overall   0.727250  0.731969  0.729582
# 57      combined      Youtube        0   0.264516  0.250000  0.257053
# 58      combined      Youtube        1   0.740506  0.754839  0.747604
# 59      combined      Youtube  overall   0.616401  0.623211  0.619702
#
#     Accuracy
# 0        NaN
# 1        NaN
# 2   0.603333
# 3        NaN
# 4        NaN
# 5   0.779399
# 6        NaN
# 7        NaN
# 8   0.167390
# 9        NaN
# 10       NaN
# 11  0.259141
# 12       NaN
# 13       NaN
# 14  0.293333
# 15       NaN
# 16       NaN
# 17  0.651384
# 18       NaN
# 19       NaN
# 20  0.798719
# 21       NaN
# 22       NaN
# 23  0.325914
# 24       NaN
# 25       NaN
# 26  0.403333
# 27       NaN
# 28       NaN
# 29  0.466210
# 30       NaN
# 31       NaN
# 32  0.731969
# 33       NaN
# 34       NaN
# 35  0.594595
# 36       NaN
# 37       NaN
# 38  0.406667
# 39       NaN
# 40       NaN
# 41  0.238464
# 42       NaN
# 43       NaN
# 44  0.580698
# 45       NaN
# 46       NaN
# 47  0.623211
# 48       NaN
# 49       NaN
# 50  0.603333
# 51       NaN
# 52       NaN
# 53  0.651384
# 54       NaN
# 55       NaN
# 56  0.731969
# 57       NaN
# 58       NaN
# 59  0.623211
