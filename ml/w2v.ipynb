# %%
import pandas as pd
import numpy as np
import os
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import re
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

folder_path_train = "..\\data\\cleaned\\train"
folder_path_test = "..\\data\\cleaned\\test"
names = ["Facebook", "Reddit", "Twitter", "Youtube"]
dfs_train = {}
dfs_test = {}

for n in names:
    dfs_train[n] = pd.read_csv(os.path.join(folder_path_train, f"{n.lower()}_train.csv"))
    dfs_test[n] = pd.read_csv(os.path.join(folder_path_test, f"{n.lower()}_test.csv"))

# %%
nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vital\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vital\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Tokenize
    tokens = word_tokenize(text)
    # Remove stop words
    tokens = [word for word in tokens if word not in stop_words]
    return tokens

for name in names:
    dfs_train[name]['tokens'] = dfs_train[name]['text'].apply(preprocess_text)
    dfs_test[name]['tokens'] = dfs_train[name]['text'].apply(preprocess_text)
    dfs_train[name]['label'] = dfs_train[name]['label'].astype(int)
    dfs_test[name]['label'] = dfs_test[name]['label'].astype(int)

# %%
#dO DATA cleaning 
#search: data cleaning in text mining to clean twitter data
# after data cleaning i need to check the data

# %%
word2vec_models = {}
for name in dfs_train.keys():
    sentences = dfs_train[name]['tokens'].tolist()
    model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
    word2vec_models[name] = model

def get_sentence_embedding(tokens, model):
    # Get the embeddings for each token
    embeddings = [model.wv[word] for word in tokens if word in model.wv]
    # Average the embeddings to get the sentence embedding
    if embeddings:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(model.vector_size)

for name in dfs_train.keys():
    dfs_train[name]['embedding'] = dfs_train[name]['tokens'].apply(lambda x: get_sentence_embedding(x, word2vec_models[name]))
    dfs_test[name]['embedding'] = dfs_test[name]['tokens'].apply(lambda x: get_sentence_embedding(x, word2vec_models[name]))

# %%
for name in dfs_train.keys():
    print(f"Class distribution in train set for {name}:")
    print(dfs_train[name]['label'].value_counts())
    print(f"Class distribution in test set for {name}:")
    print(dfs_test[name]['label'].value_counts())
# Out:
# Class distribution in train set for Facebook:
# label
# 1    1891
# 0     685
# Name: count, dtype: int64
# Class distribution in test set for Facebook:
# label
# 1    473
# 0    172
# Name: count, dtype: int64
# Class distribution in train set for Reddit:
# label
# 0    11836
# 1     3252
# Name: count, dtype: int64
# Class distribution in test set for Reddit:
# label
# 0    2959
# 1     813
# Name: count, dtype: int64
# Class distribution in train set for Twitter:
# label
# 1    16496
# 0     3330
# Name: count, dtype: int64
# Class distribution in test set for Twitter:
# label
# 1    4124
# 0     833
# Name: count, dtype: int64
# Class distribution in train set for Youtube:
# label
# 1    1891
# 0     685
# Name: count, dtype: int64
# Class distribution in test set for Youtube:
# label
# 1    473
# 0    172
# Name: count, dtype: int64

# %%
for name in dfs_train.keys():
    X_test = np.vstack(dfs_test[name]['embedding'].values)
    y_test = dfs_test[name]['label']
    
    classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    classifier.fit(np.vstack(dfs_train[name]['embedding'].values), dfs_train[name]['label'])
    y_pred = classifier.predict(X_test)
    
    print(f"Predicted class distribution for {name}:")
    print(pd.Series(y_pred).value_counts())
# Out:
# Predicted class distribution for Facebook:
# 1    474
# 0    171
# Name: count, dtype: int64
# Predicted class distribution for Reddit:
# 0    2999
# 1     773
# Name: count, dtype: int64
# Predicted class distribution for Twitter:
# 1    4156
# 0     801
# Name: count, dtype: int64
# Predicted class distribution for Youtube:
# 1    474
# 0    171
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Plot embeddings for each dataset
fig, axs = plt.subplots(2, 2, figsize=(14, 12))

datasets = ['Facebook', 'Twitter', 'Reddit', 'Youtube']
for ax, name in zip(axs.flatten(), datasets):
    pca = PCA(n_components=2)
    embeddings = np.vstack(dfs_train[name]['embedding'].values)
    labels = dfs_train[name]['label'].values
    reduced_embeddings = pca.fit_transform(embeddings)
    
    ax.scatter(reduced_embeddings[labels == 0, 0], reduced_embeddings[labels == 0, 1], c='red', label='Class 0', alpha=0.5)
    ax.scatter(reduced_embeddings[labels == 1, 0], reduced_embeddings[labels == 1, 1], c='blue', label='Class 1', alpha=0.5)
    ax.set_title(f'PCA of {name} Embeddings')
    ax.set_xlabel('PCA Component 1')
    ax.set_ylabel('PCA Component 2')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

results = []

# Train on each dataset and test on all datasets
for train_name in names:
    # Prepare training data
    X_train = np.vstack(dfs_train[train_name]['embedding'].values)
    y_train = dfs_train[train_name]['label']
    
    # Train the classifier
    classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    classifier.fit(X_train, y_train)
    
    for test_name in names:
        # Prepare testing data
        X_test = np.vstack(dfs_test[test_name]['embedding'].values)
        y_test = dfs_test[test_name]['label']
        
        # Predict on the test data
        y_pred = classifier.predict(X_test)
        report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
        recall = recall_score(y_test, y_pred, average='weighted')
        f1 = f1_score(y_test, y_pred, average='weighted')
        
        # Collect results for each class
        for cls in ['0', '1']:
            results.append({
                'Train Dataset': train_name,
                'Test Dataset': test_name,
                'Class': cls,
                'Precision': report[cls]['precision'],
                'Recall': report[cls]['recall'],
                'F1-Score': report[cls]['f1-score'],
                'Accuracy': np.nan  # Accuracy is not class-specific
            })
        
        # Include the overall metrics for the test dataset
        results.append({
            'Train Dataset': train_name,
            'Test Dataset': test_name,
            'Class': 'overall',
            'Precision': precision,
            'Recall': recall,
            'F1-Score': f1,
            'Accuracy': accuracy
        })

# Train on combined datasets and test on each dataset separately
X_train_combined = np.vstack([np.vstack(dfs_train[name]['embedding'].values) for name in names])
y_train_combined = np.hstack([dfs_train[name]['label'] for name in names])

# Train the classifier on combined datasets
classifier_combined = RandomForestClassifier(n_estimators=100, random_state=42)
classifier_combined.fit(X_train_combined, y_train_combined)

for test_name in names:
    # Prepare testing data
    X_test = np.vstack(dfs_test[test_name]['embedding'].values)
    y_test = dfs_test[test_name]['label']
    
    # Predict on the test data
    y_pred = classifier_combined.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    # Collect results for each class
    for cls in ['0', '1']:
        results.append({
            'Train Dataset': 'combined',
            'Test Dataset': test_name,
            'Class': cls,
            'Precision': report[cls]['precision'],
            'Recall': report[cls]['recall'],
            'F1-Score': report[cls]['f1-score'],
            'Accuracy': np.nan  # Accuracy is not class-specific
        })
    
    # Include the overall metrics for the test dataset
    results.append({
        'Train Dataset': 'combined',
        'Test Dataset': test_name,
        'Class': 'overall',
        'Precision': precision,
        'Recall': recall,
        'F1-Score': f1,
        'Accuracy': accuracy
    })

results_df = pd.DataFrame(results)

# Save the results DataFrame to a CSV file
results_df.to_csv('results/w2v_classification_results.csv', index=False)

# Display the results DataFrame
print(results_df)
# Out:
#    Train Dataset Test Dataset    Class  Precision    Recall  F1-Score  \
# 0       Facebook     Facebook        0   0.233918  0.232558  0.233236
# 1       Facebook     Facebook        1   0.721519  0.723044  0.722281
# 2       Facebook     Facebook  overall   0.591492  0.592248  0.591869
# 3       Facebook       Reddit        0   0.793258  0.119297  0.207403
# 4       Facebook       Reddit        1   0.216712  0.886839  0.348309
# 5       Facebook       Reddit  overall   0.668992  0.284730  0.237773
# 6       Facebook      Twitter        0   0.178744  0.044418  0.071154
# 7       Facebook      Twitter        1   0.832421  0.958778  0.891143
# 8       Facebook      Twitter  overall   0.722574  0.805124  0.753347
# 9       Facebook      Youtube        0   0.272189  0.267442  0.269795
# 10      Facebook      Youtube        1   0.735294  0.739958  0.737619
# 11      Facebook      Youtube  overall   0.611800  0.613953  0.612866
# 12        Reddit     Facebook        0   0.266667  1.000000  0.421053
# 13        Reddit     Facebook        1   0.000000  0.000000  0.000000
# 14        Reddit     Facebook  overall   0.071111  0.266667  0.112281
# 15        Reddit       Reddit        0   0.780594  0.791146  0.785834
# 16        Reddit       Reddit        1   0.200517  0.190652  0.195460
# 17        Reddit       Reddit  overall   0.655567  0.661718  0.658588
# 18        Reddit      Twitter        0   0.165271  0.545018  0.253631
# 19        Reddit      Twitter        1   0.828507  0.443986  0.578150
# 20        Reddit      Twitter  overall   0.717053  0.460964  0.523616
# 21        Reddit      Youtube        0   0.270992  0.825581  0.408046
# 22        Reddit      Youtube        1   0.752066  0.192389  0.306397
# 23        Reddit      Youtube  overall   0.623780  0.361240  0.333504
# 24       Twitter     Facebook        0   0.262626  0.151163  0.191882
# 25       Twitter     Facebook        1   0.732601  0.845666  0.785083
# 26       Twitter     Facebook  overall   0.607274  0.660465  0.626896
# 27       Twitter       Reddit        0   0.782700  0.250760  0.379831
# 28       Twitter       Reddit        1   0.214943  0.746617  0.333792
# 29       Twitter       Reddit  overall   0.660329  0.357635  0.369908
# 30       Twitter      Twitter        0   0.182272  0.175270  0.178703
# 31       Twitter      Twitter        1   0.834697  0.841174  0.837923
# 32       Twitter      Twitter  overall   0.725060  0.729272  0.727144
# 33       Twitter      Youtube        0   0.268293  0.127907  0.173228
# 34       Twitter      Youtube        1   0.733570  0.873150  0.797297
# 35       Twitter      Youtube  overall   0.609496  0.674419  0.630879
# 36       Youtube     Facebook        0   0.259036  0.750000  0.385075
# 37       Youtube     Facebook        1   0.707483  0.219873  0.335484
# 38       Youtube     Facebook  overall   0.587897  0.361240  0.348708
# 39       Youtube       Reddit        0   0.782975  0.345049  0.479005
# 40       Youtube       Reddit        1   0.214749  0.651907  0.323072
# 41       Youtube       Reddit  overall   0.660502  0.411188  0.445396
# 42       Youtube      Twitter        0   0.173958  0.200480  0.186280
# 43       Youtube      Twitter        1   0.833375  0.807711  0.820342
# 44       Youtube      Twitter  overall   0.722563  0.705669  0.713791
# 45       Youtube      Youtube        0   0.233918  0.232558  0.233236
# 46       Youtube      Youtube        1   0.721519  0.723044  0.722281
# 47       Youtube      Youtube  overall   0.591492  0.592248  0.591869
# 48      combined     Facebook        0   0.233918  0.232558  0.233236
# 49      combined     Facebook        1   0.721519  0.723044  0.722281
# 50      combined     Facebook  overall   0.591492  0.592248  0.591869
# 51      combined       Reddit        0   0.780594  0.791146  0.785834
# 52      combined       Reddit        1   0.200517  0.190652  0.195460
# 53      combined       Reddit  overall   0.655567  0.661718  0.658588
# 54      combined      Twitter        0   0.183064  0.176471  0.179707
# 55      combined      Twitter        1   0.834858  0.840931  0.837884
# 56      combined      Twitter  overall   0.725327  0.729272  0.727280
# 57      combined      Youtube        0   0.233918  0.232558  0.233236
# 58      combined      Youtube        1   0.721519  0.723044  0.722281
# 59      combined      Youtube  overall   0.591492  0.592248  0.591869
#
#     Accuracy
# 0        NaN
# 1        NaN
# 2   0.592248
# 3        NaN
# 4        NaN
# 5   0.284730
# 6        NaN
# 7        NaN
# 8   0.805124
# 9        NaN
# 10       NaN
# 11  0.613953
# 12       NaN
# 13       NaN
# 14  0.266667
# 15       NaN
# 16       NaN
# 17  0.661718
# 18       NaN
# 19       NaN
# 20  0.460964
# 21       NaN
# 22       NaN
# 23  0.361240
# 24       NaN
# 25       NaN
# 26  0.660465
# 27       NaN
# 28       NaN
# 29  0.357635
# 30       NaN
# 31       NaN
# 32  0.729272
# 33       NaN
# 34       NaN
# 35  0.674419
# 36       NaN
# 37       NaN
# 38  0.361240
# 39       NaN
# 40       NaN
# 41  0.411188
# 42       NaN
# 43       NaN
# 44  0.705669
# 45       NaN
# 46       NaN
# 47  0.592248
# 48       NaN
# 49       NaN
# 50  0.592248
# 51       NaN
# 52       NaN
# 53  0.661718
# 54       NaN
# 55       NaN
# 56  0.729272
# 57       NaN
# 58       NaN
# 59  0.592248
